# %%
# %run /Users/akshay/Desktop/akshayk_project/Project.ipynb

# %%
d = ReadData('/Users/akshay/Desktop/akshayk_project/Stores.csv')
df = d.getDataFrame()
df
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0            1        1659             1961                   530        66490
# 1            2        1461             1752                   210        39820
# 2            3        1340             1609                   720        54010
# 3            4        1451             1748                   620        53730
# 4            5        1770             2111                   450        46620
# ..         ...         ...              ...                   ...          ...
# 891        892        1582             1910                  1080        66390
# 892        893        1387             1663                   850        82080
# 893        894        1200             1436                  1060        76440
# 894        895        1299             1560                   770        96610
# 895        896        1174             1429                  1110        54340
#
# [896 rows x 5 columns]

# %%
c = Calculation(df)
data = c.getStatistics(4)
c.getCorelation(1,4,df)
# Out:
# Mean: 59351.30580357143
# Median is: 58605.0
# Standard Deviation of is: 17181.14616881951
# 75% percentile of store sales: 71872.5
# (0.9999933713963423, 2.0486440364071682e-08)

# %%
v = Visualizations(df)
v.firstscatterplot()
v.secondscatterplot('Daily_Customer_Count','Store_Sales')
v.histplot('Store_Sales')
# Out:
# /var/folders/zz/x23587pj6wg74rj89_9jchfc0000gn/T/ipykernel_16449/3622792249.py:12: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   f.show()
# /var/folders/zz/x23587pj6wg74rj89_9jchfc0000gn/T/ipykernel_16449/3622792249.py:20: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   f.show()

# %%
y=df['Store_Sales']
x=df.drop(['Store ID ','Daily_Customer_Count','Store_Sales'],axis=1)
        
p = Predict(x,y)
p.trainAndTestModel()
x1 = np.array([[1461,1752]], np.int32)
p.predict(x1)
# Out:
# Store Sales predicted by LinearRegression(): [59005.63010163]
# Store Sales predicted by KNeighborsRegressor(): [55818.]
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
